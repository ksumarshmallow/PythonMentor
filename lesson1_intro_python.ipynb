# %% [markdown]
# # **L1. Знакомство с Python: "Hello, World"**

# %% [markdown]
# План:
# - Пишем первую программу - здороваемся с миром
# - Узнаем, что такое функция, переменная и аргументы в python
# - Освоим функции `print()` и `type()`

# %% [markdown]
# # **1. Введение в Python**

# %% [markdown]
# Напишем первую программу. Поздороваемся с миром!

# %%
print('Hello, World!')
# Out:
# Hello, World!

# %% [markdown]
# <div style="background-color: rgba(31, 114, 209, 0.41); padding: 15px; margin: 15px; border-radius: 8px; border-left: 5px solid rgb(13, 86, 169);">
#
# 🧩 **Задание**
#
# Измени Hello, World на свое сообщение :)
#
# </div>

# %%
# ниже ты можешь написать свое сообщение!

# %% [markdown]
# ---

# %% [markdown]
# ## 1.1 Типы данных

# %% [markdown]
# <div style="background-color: rgba(56, 17, 90, 0.3); padding: 15px; margin: 15px; border-radius: 8px; border-left: 5px solid #8A2BE2;">
#
# >**Тип данных** — это характеристика значения, которая определяет, какие **операции** с ним возможны и как оно хранится в памяти.
#
# Глобально три основных типа данных:
#
# 1. *Строка* (`str`)
#    - Любые символы в кавычках — или двойных (`""`) или одинарных (`''`). Главное, чтобы начиналась и заканчивалась одним типом кавычек.
#    - Пример:
#      ```python
#      "Привет"
#      'Динозавр'
#      "12345"
#      ```
#
# 2. *Целое число* (`int`)
#    - Задается просто числом без кавычек.
#    - Может быть положительным, отрицательным или нулем.
#    - Пример:
#      ```python
#      8
#      -42
#      0
#      ```
#
# 3. *Число с плавающей запятой* (`float`)
#    - Тоже задаtтся без кавычек, но обязательно с точкой, разделяющей целую и дробную части.
#    - Пример:
#      ```python
#      3.14
#      -0.5
#      8.0
#      ```
#
# **❗️ВАЖНО❗️** **Число, заключенное в кавычки, являетcя строкой**
# </div>

# %% [markdown]
# При запуске ячейки (`Run` или `Shift+Enter`) Jupyter-notebook выводит значения (в output - внизу ячейки), которые мы "оставляем" на последней строке в запускаемой ячейке.

# %% [markdown]
# 1. **Строка**

# %%
'Динозавр'

# %% [markdown]
# Вне зависимости от напечатанных нам кавычек весь output будет выделяться в одинарных кавычках - пугаться не нужно

# %%
"питон"

# %% [markdown]
# Число в кавычках - тоже строка

# %%
"392483208"

# %% [markdown]
# Если заключим строку в кавычки разных типов (одна одинарная, вторая - двойная) - будет ошибка.

# %%
"8239478923'

# %% [markdown]
# 2. **Целое число**

# %% [markdown]
# Числа, в отличие от строк, в output ячейки не будут заключены в кавычки

# %%
38402

# %% [markdown]
# 3. **Нецелое число**

# %% [markdown]
# Дробную и целую части отделяем **точкой**

# %%
3.14

# %% [markdown]
# При отделении **запятой** значений **любых форматов**:
# - В output'е ячейки также будут перечисляться один за другим через запятую
# - Все значения будут заключены в скобки (так называемый *кортеж*, но о нем - на других занятиях)

# %%
"это строка", 28432984, "строка с, запятой", 3.14

# %% [markdown]
# ---

# %% [markdown]
# ## 1.2 Функции, параметры и аргументы

# %% [markdown]
# <div style="background-color: rgba(56, 17, 90, 0.3); padding: 15px; margin: 15px; border-radius: 8px; border-left: 5px solid #8A2BE2;">
#
# > **Функция** — это волшебная машинка в Python: мы даем ей что‑то на вход, она внутри делает свое дело и возвращает результат.
#
# Python приобрел много таких машинок — их называют **встроенные функции**. Например:
# - `print()` — печатает на экране то, что дадим ей в руки.
# - `input()` — спрашивает у тебя что‑то и отдаёт ответ.
# - `len()` — считает длину строки или список.
# - `type()` — говорит, к какому типу принадлежит значение.
# - `int()`, `float()` — превращают текст или числа из одного вида в другой.
#
# Полный список встроенных функций можно глянуть здесь: https://docs.python.org/3/library/functions.html
# ```

# %% [markdown]
# **Как «запустить» функцию?**
#
# 1. Пишем имя функции.
# 2. Сразу после имени ставим круглые скобки `()`.
# 3. Внутрь скобок можно положить **аргументы** — то, что нужно функции «пожевать» и обработать.
#
# Пример:
# ```python
#     название_функции(аргумент1, аргумент2, ...)

# %% [markdown]
# Если сейчас не до конца понятно - это ок! С аргументами и параметрами будем знакомиться и разбираться при разборе конкретных функций

# %% [markdown]
# #### *Функция `type()`*

# %% [markdown]
# Функция `type()` позволяет проверить тип данных - мы ей скармливаем данные, а она возвращает его тип.
# - `str` - строковый тип
# - `int` - целое число
# - `float` - нецелое число

# %%
type("Привет!")

# %%
type(49230493)

# %%
type(93.23)

# %%
type("7.0")

# %% [markdown]
# ---

# %% [markdown]
# ## 1.3 Переменные

# %% [markdown]
# <div style="background-color: rgba(56, 17, 90, 0.3); padding: 15px; margin: 15px; border-radius: 8px; border-left: 5px solid #8A2BE2;">
#
# > **Переменная** — это как коробочка с табличкой: ты кладёшь в неё какое-то значение и можешь потом достать, просто назвав имя этой коробочки.
#
# Представь, что ты пишешь на коробке слово `кошка`, а внутрь кладешь `"Мурка"`. Теперь каждый раз, когда напишешь `кошка`, Python поймет, что ты имеешь в виду `"Мурка"`.
#
# Синтаксис **создания переменной** простой:
# ```python
#     название_переменной = значение
# ```
#
# После того как переменная создана, ты можешь ее:
# - выводить на экран: `print(age)`
# - использовать в вычислениях: `age + 1`
# - передавать в функции
#
# **Использование переменной = Использование значения, которое мы в него положили**
#
# </div>

# %% [markdown]
# Примеры:

# %%
age = 11
age

# %%
name = "Андрей"
name

# %% [markdown]
# <div style="background-color: rgba(200, 79, 68, 0.3); padding: 15px; margin: 15px; border-radius: 8px; border-left: 5px solidrgb(231, 107, 76);">
#
# **Названия переменных**
# - ✅ Не заключаются в кавычки
# - ✅ Можно использовать любой алфавит — хоть английский, хоть русский.
# - ❌ Нельзя использовать пробелы, тире, эмоджи и знаки препинания (кроме _)
# - ❌ Нельзя начинать название с цифры
#
# 🧠 Лучше называть переменные понятно — чтобы потом легко было вспомнить, что они означают!
#
# </div>

# %%
число = 5
name = "Дино"
name, число

# %% [markdown]
# <div style="background-color: rgba(31, 114, 209, 0.41); padding: 15px; margin: 15px; border-radius: 8px; border-left: 5px solid rgb(13, 86, 169);">
#
# 🧩 **Задание**
#
# - Создать три переменные **разных** типов
# - Вывести ее тип (с помощью `type()`)
#
# </div>

# %%
# В этой ячейке можешь приступать к решению

# %% [markdown]
# ---

# %% [markdown]
# # **2. Работа со строками.**

# %% [markdown]
# Со строками можно делать много всего! Здесь мы посмотрим базовые методы

# %% [markdown]
# ## 2.1 🔤 Конкатенация (=склеивание) строк

# %% [markdown]
# Можно соединять строки с помощью `+`, как скотчем. Например, сложение строки 'Яб' и 'локо' даст 'Яблоко'

# %%
"Привет" + "мир"

# %% [markdown]
# Пробелы и знаки препинания - тоже символы

# %%
"Привет, " + "мир" + "!"

# %% [markdown]
# Можно все делать через **переменные**

# %%
hello = "Привет, "
name = "Марк"

hello + name

# %% [markdown]
# ---

# %% [markdown]
# ## 2.2 🔁 Повторение строк

# %% [markdown]
# Можно «умножить» строку на число — тогда она повторится несколько раз. Умножение в python задается через `*`

# %%
"привет" * 4

# %% [markdown]
# ---

# %% [markdown]
# ## 2.3 📏 Длина строки - функция `len()`
# Измерить длину строки = посчитать количество символов в ней. За это в python ответственная функция  **`len()`**:

# %%
name = "Брандашмыг"
len(name)

# %% [markdown]
# Пробелы и знаки препинания тоже считаются за символы!

# %%
name = " Брандашмыг !"
len(name)

# %% [markdown]
# Категорически запрещается умножать строку на строку :)

# %%
'3' * '5'

# %% [markdown]
# ---

# %% [markdown]
# ## 2.4 🖨 Печать строк - функция **`print()`**

# %% [markdown]
# Функция `print()` выводит текст на экран. Внутрь можно положить строки, числа, переменные — и всё напечатается!

# %%
name = "Рексик"
print(name)

# %% [markdown]
# В целом видим мы то же самое, что и просто при оставлении значения на последней строке в Jupyter Notebook. Но `print()` позволяет это сделать в любом месте ячейки.

# %% [markdown]
# Можно также напечатать несколько переменных подряд:
# - В `print()` перечисляем их через запятую
# - По умолчанию в выводе ячейки разделяются пробелом

# %%
name = "Рексик"
print('привет', name)

# %% [markdown]
# Если вызовем несколько функций `print()` в одной ячейке - каждый результат будет печататься с новой строки!

# %%
print('строка 1')
print('строка 2')
print('строка 3')

# %% [markdown]
# На самом деле мы можем управлять тем, как именно `print()` печатает текст:
# - что будет между частями текста, если мы передаём несколько штук сразу (по умолчанию — пробел)
# - и что будет в конце строки (по умолчанию — перевод строки, то есть новая строчка)
#
# Все это можно настроить, передав в `print()` специальные **параметры**.

# %% [markdown]
# <div style="background-color: rgba(56, 17, 90, 0.3); padding: 15px; margin: 15px; border-radius: 8px; border-left: 5px solid #8A2BE2;">
#
# **Параметр** — это «имя настройки», которое понимает функция. Мы передаем значение этой настройки с помощью **аргументов**.

# %% [markdown]
# Например, в примере ниже:
# - `sep` — **параметр**, `"–"` — **аргумент** (он говорит, чем разделять)
# - `end` — **параметр**, `"!"` — **аргумент** (он говорит, чем заканчивать строку)

# %%
print("А", "Б", sep="-", end="!")

# %% [markdown]
# <div style="background-color: rgba(56, 17, 90, 0.3); padding: 15px; margin: 15px; border-radius: 8px; border-left: 5px solid #8A2BE2;">
#
# **Параметры у функции `print()`**:
# 1. `sep` — separator, разделитель между частями. По умолчанию — пробел.
# 2. `end` — end, символ в конце строки. По умолчанию — перевод строки (`"\n"`), то есть "курсор" переходит на следующую строку.
#
# Можно менять эти параметры, чтобы `print()` вел себя так, как тебе хочется. Главное требование к передаваемым **аргументам** у обоих **параметров** - чтобы они были **строками**
#
# </div>

# %%
print("А", "Б", sep=" и ", end=" сидели на трубе")

# %% [markdown]
# <div style="background-color: rgba(31, 114, 209, 0.41); padding: 15px; margin: 15px; border-radius: 8px; border-left: 5px solid rgb(13, 86, 169);">
#
# 🧩 **Задание**
#
# Выведи (любые) три слова, разделенные символом `-`.
#
# Например, для слов "A", "B" и "C" ожидается:
# ```python
#     A-B-C
# ```
#
# </div>

# %% [markdown]
# <div style="background-color: rgba(31, 114, 209, 0.41); padding: 15px; margin: 15px; border-radius: 8px; border-left: 5px solid rgb(13, 86, 169);">
#
# 🧩 **Задание**
#
# Выведи те же слова, но чтобы они шли без пробелов и заканчивались восклицательным знаком.
#
# Например, для слов "A", "B" и "C" ожидается:
# ```python
#     ABC!
# ```
#
# </div>

# %% [markdown]
# <div style="background-color: rgba(31, 114, 209, 0.41); padding: 15px; margin: 15px; border-radius: 8px; border-left: 5px solid rgb(13, 86, 169);">
#
# 🧩 **Задание**
#
# Просто поэкспериментируй!
# - замени разделитель на `->`
# - попробуй `end=" :) \n"`
# - ... придумай свой вариант разделителя и окончания
#
#
# </div>

# %% [markdown]
# ---

# %% [markdown]
# ## 2.5 🔀 Преобразование типов

# %% [markdown]
# Если нужно получить число, надо **преобразовать тип данных**.

# %% [markdown]
# <div style="background-color: rgba(56, 17, 90, 0.3); padding: 15px; margin: 15px; border-radius: 8px; border-left: 5px solid #8A2BE2;">
#
# Для преобразования типов в Python есть **встроенные функции**:
#
# * `str()` — превращает в **строку**
# * `int()` — превращает в **целое число**
# * `float()` — превращает в **число с запятой** (через точку!)

# %% [markdown]
# 1. **Строка** (`str`) — самая сильная

# %% [markdown]
# Можно превратить любое число в строку:

# %%
str(5)

# %%
str(3.14)

# %% [markdown]
# 2. **Float** — середнячок

# %% [markdown]
# Можно превратить целое число в `float`, или строку — если в ней записано число:

# %%
float(5)

# %%
float("7.81")

# %%
float("10")

# %% [markdown]
# Но если строка не похожа на число — будет ошибка:

# %%
float("мороженко")

# %% [markdown]
# 3. **Целое число** (`int`) — самое слабое

# %% [markdown]
# Можно перевести `float` в `int`, но мы потеряем дробную часть (округление вниз)

# %%
int(7.89)

# %% [markdown]
# Также можно перевести строку в целое число, но если в ней **только** цифры:

# %%
int("12")

# %% [markdown]
# Переводить другие строки - нельзя, будет ошибка

# %%
int("12.2")

# %%
int("Какая-то строка")
