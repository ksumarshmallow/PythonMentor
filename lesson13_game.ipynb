# %% [markdown]
# # **L13. Библиотека `random` и игры**

# %% [markdown]
# ## Библиотека `random`

# %%
import random

# %%
# случайное целое число от 1 до 10
random.randint(1, 10)
# Out:
# 10

# %%
# 10 случайных чисел от -100 до 100
[random.randint(-100, 100) for i in range(10)]
# Out:
# [1, -23, 20, 40, 78, -50, 3, -80, 23, -68]

# %%
# перменная i не нужна - ее можно заменить _ (не перегружаем память переменными)
[random.randint(-100, 100) for _ in range(10)]
# Out:
# [-78, -48, -30, -35, 90, 43, 50, -32, 41, 56]

# %%
# выбор случайного значения из списка
random.choice(['кот', 'мышь', 'собака'])
# Out:
# 'кот'

# %% [markdown]
# ## Мини «Слот-машина»
#
# На экране выводятся 3 случайных символа (🍒 🍋 🔔).
# - Если все одинаковые — победа.

# %% [markdown]
# ## «Выбор дверей»
#
# Игроку предлагают 3 двери. За одной — приз 🎁, за другими — пусто. Игрок выбирает номер двери. Можно сделать несколько уровней
